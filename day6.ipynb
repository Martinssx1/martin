# %%
#function:
def greet():#A function with no parameter or arguement
    return 'welcome to python class'
print(greet())
# Out:
# welcome to python class

# %%
def greet2(name):
    return f'welcome to python class{name}'
print(greet2('ade'))
# Out:
# welcome to python classade

# %%
print(greet2('jane'))
# Out:
# welcome to python classjane

# %%
def bag_check(type_of_bag,color,bagweight):
    if bagweight <=23:
        print('normal bag weight no chargers')
    elif bagweight >=24 and bagweight<=30:
        print('above normal bag weight by little kg therefore you would be charged N10,000')
    elif bagweight >=31 and bagweight<=40:
        print('above normal bag weight by medium kg therefore you be charged N20,000')
    else:
        print('above normal bag weight by large kg therefore you would be charged a way bill of N40,000')
print(bag_check('medium box','black',35))
# Out:
# above normal bag weight by medium kg therefore you be charged N20,000
# None

# %%
def bag_check(type_of_bag,color,bagweight=23):
    if bagweight <=23:
        print('normal bag weight no chargers')
    elif bagweight >=24 and bagweight<=30:
        print('above normal bag weight by little kg therefore you would be charged N10,000')
    elif bagweight >=31 and bagweight<=40:
        print('above normal bag weight by medium kg therefore you be charged N20,000')
    else:
        print('above normal bag weight by large kg therefore you would be charged a way bill of N40,000')
print(bag_check('medium box','black',59))
# Out:
# above normal bag weight by large kg therefore you would be charged a way bill of N40,000
# None

# %%
def dice_roller():
    import random
    player1score=0
    player2score=0
    for i in range(1,11):
        dice1=random.randint(1,6)+random.randint(1,6)
        dice2=random.randint(1,6)+random.randint(1,6)
        
        if dice1>dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER ONE WINS')
            player1score=player2score +5
            print('\n')
        elif dice2 >dice1 :
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER TWO  WINS')
            player2score=player1score +5
            print('\n')
        elif dice1 ==dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'IT IS A DRAW')
            player1score=player1score +2
            player2score=player2score +2
            print('\n')
    if player1score>player2score:
        print(f'PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF{player1score}')
    elif player2score >player1score:
        print(f'PLAYER TWO IS THE OVERALL WINNER WITH A TOTAL POINT OF {player2score}')
    else:
        print('NO WINNER THEREFORE IT IS A DRAW')
dice_roller()
# Out:
# PLAYER ONE SCORE 2
# PLAYER TWO SCORE 9
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 11
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 8
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 6
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 5
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 2
# PLAYER ONE WINS
#
#
# PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF24

# %%
def dice_roller():
    import random
    player1score=0
    player2score=0
    counter=1
    while counter <=10:
        dice1=random.randint(1,6)+random.randint(1,6)
        dice2=random.randint(1,6)+random.randint(1,6)
        
        if dice1>dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER ONE WINS')
            player1score=player2score +5
            print('\n')
        elif dice2 >dice1 :
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'PLAYER TWO  WINS')
            player2score=player1score +5
            print('\n')
        elif dice1 ==dice2:
            print(f'PLAYER ONE SCORE {dice1}')
            print(f'PLAYER TWO SCORE {dice2}')
            print(f'IT IS A DRAW')
            player1score=player1score +2
            player2score=player2score +2
            print('\n')
            counter+=1
    if player1score>player2score:
        print(f'PLAYER ONE IS THE OVERALL WINNER WITH A TOTAL POINT OF{player1score}')
    elif player2score >player1score:
        print(f'PLAYER TWO IS THE OVERALL WINNER WITH A TOTAL POINT OF {player2score}')
    else:
        print('NO WINNER THEREFORE IT IS A DRAW')
dice_roller()
# Out:
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 5
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 12
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 11
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 8
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 6
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 7
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 3
# PLAYER TWO SCORE 3
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 11
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 8
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 5
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 11
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 9
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 5
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 9
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 11
# PLAYER TWO SCORE 10
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 4
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 6
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 8
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 9
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 6
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 7
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 9
# PLAYER TWO SCORE 3
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 8
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 7
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 12
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 3
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 10
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 12
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 9
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 6
# PLAYER ONE WINS
#
#
# PLAYER ONE SCORE 6
# PLAYER TWO SCORE 6
# IT IS A DRAW
#
#
# PLAYER ONE SCORE 8
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 4
# PLAYER TWO SCORE 10
# PLAYER TWO  WINS
#
#
# PLAYER ONE SCORE 7
# PLAYER TWO SCORE 7
# IT IS A DRAW
#
#
# PLAYER TWO IS THE OVERALL WINNER WITH A TOTAL POINT OF 160

# %%
def average(*num):
    print(type(num))
    avg =sum(num)/len(num)
    return f'the average score of the following numbers{num} is {avg}'
average(47,89,56,85,24,69)
# Out:
# <class 'tuple'>
# 'the average score of the following numbers(47, 89, 56, 85, 24, 69) is 61.666666666666664'

# %%
import random
numbers=[]
counter=1
while counter<=50:
    numbers.append(random.randint(45,80))
    counter+=1
print (numbers)
# Out:
# [80, 73, 74, 54, 50, 72, 69, 71, 61, 65, 65, 68, 74, 46, 77, 63, 78, 53, 46, 76, 67, 80, 69, 70, 62, 76, 75, 58, 64, 57, 51, 76, 74, 56, 73, 60, 61, 80, 48, 71, 48, 45, 54, 57, 68, 58, 64, 77, 80, 63]

# %%
average(*numbers)
# Out:
# <class 'tuple'>
# 'the average score of the following numbers(80, 73, 74, 54, 50, 72, 69, 71, 61, 65, 65, 68, 74, 46, 77, 63, 78, 53, 46, 76, 67, 80, 69, 70, 62, 76, 75, 58, 64, 57, 51, 76, 74, 56, 73, 60, 61, 80, 48, 71, 48, 45, 54, 57, 68, 58, 64, 77, 80, 63) is 65.14'

# %%
def details(**record):
    print(type(record))
    for key,value in record.items():
        print(f'{key}:::{value}')
details(name='Ade',age=45,gender='male')
# Out:
# <class 'dict'>
# name:::Ade
# age:::45
# gender:::male

# %%
bmi=(w/(h**2))
